# %%
import pandas as pd
import numpy as np

# %%
sfp_data = pd.read_csv('bp/Building_Permits.csv')
np.random.seed(0)
# Out:
# C:\Users\abhin\AppData\Local\Temp\ipykernel_21704\120410615.py:1: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   sfp_data = pd.read_csv('bp/Building_Permits.csv')

# %%
sfp_data.sample(5)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 40553   201403039652            8            otc alterations permit
# 169731  201510159735            3  additions alterations or repairs
# 19180        M409787            8            otc alterations permit
# 68047   201411191888            8            otc alterations permit
# 64238        M527228            8            otc alterations permit
#
#        Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 40553            03/03/2014  3732  008            400                  NaN
# 169731           10/15/2015  2609  028             79                  NaN
# 19180            07/22/2013  4624  031            178                  NaN
# 68047            11/19/2014  0039  109            294                  NaN
# 64238            10/14/2014  1251  002            707                  NaN
#
#         Street Name Street Suffix  ...  Existing Construction Type  \
# ...

# %%
len(sfp_data)
# Out:
# 198900

# %%
missing_values_count = sfp_data.isnull().sum()
missing_values_count
# Out:
# Permit Number                                  0
# Permit Type                                    0
# Permit Type Definition                         0
# Permit Creation Date                           0
# Block                                          0
# Lot                                            0
# Street Number                                  0
# Street Number Suffix                      196684
# Street Name                                    0
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Current Status                                 0
# Current Status Date                            0
# Filed Date                                     0
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# ...

# %%
#finding percentage of missing values

total_cells = np.product(sfp_data.shape)
total_missing_cells = missing_values_count.sum()

missing_percentage = (total_missing_cells/total_cells)*100
print("missing_cells percentage: ", missing_percentage)
# Out:
# missing_cells percentage:  26.26002315058403

# %%
rows_with_missing_dropped = sfp_data.dropna(axis=1)
columns_with_missing_dropped = sfp_data.dropna()

print("Original shape of data:", sfp_data.shape)
print("Shape after dropping rows with missing values:", rows_with_missing_dropped.shape)
print("Shape after dropping columns with missing values:", columns_with_missing_dropped.shape)

print(rows_with_missing_dropped.head())
print(columns_with_missing_dropped.head())
# Out:
# Original shape of data: (198900, 43)
# Shape after dropping rows with missing values: (198900, 12)
# Shape after dropping columns with missing values: (0, 43)
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Current Status  \
# 0           05/06/2015  0326  023            140       Ellis        expired
# 1           04/19/2016  0306  007            440       Geary         issued
# 2           05/27/2016  0595  203           1647     Pacific      withdrawn
# 3           11/07/2016  0156  011           1230     Pacific       complete
# ...

# %%
#replacing all missing values with 0
subset_sfp_data = sfp_data.loc[:, 'Permit Type' : 'Issued Date'].head()

subset_sfp_data
# Out:
#    Permit Type            Permit Type Definition Permit Creation Date Block  \
# 0            4                      sign - erect           05/06/2015  0326
# 1            4                      sign - erect           04/19/2016  0306
# 2            3  additions alterations or repairs           05/27/2016  0595
# 3            8            otc alterations permit           11/07/2016  0156
# 4            6                       demolitions           11/28/2016  0342
#
#    Lot  Street Number Street Number Suffix Street Name Street Suffix  Unit  \
# 0  023            140                  NaN       Ellis            St   NaN
# 1  007            440                  NaN       Geary            St   0.0
# 2  203           1647                  NaN     Pacific            Av   NaN
# 3  011           1230                  NaN     Pacific            Av   0.0
# 4  001            950                  NaN      Market            St   NaN
#
# ...

# %%
subset_sfp_data.fillna(value=0)
subset_sfp_data
# Out:
#    Permit Type            Permit Type Definition Permit Creation Date Block  \
# 0            4                      sign - erect           05/06/2015  0326
# 1            4                      sign - erect           04/19/2016  0306
# 2            3  additions alterations or repairs           05/27/2016  0595
# 3            8            otc alterations permit           11/07/2016  0156
# 4            6                       demolitions           11/28/2016  0342
#
#    Lot  Street Number Street Number Suffix Street Name Street Suffix  Unit  \
# 0  023            140                  NaN       Ellis            St   NaN
# 1  007            440                  NaN       Geary            St   0.0
# 2  203           1647                  NaN     Pacific            Av   NaN
# 3  011           1230                  NaN     Pacific            Av   0.0
# 4  001            950                  NaN      Market            St   NaN
#
# ...

# %%
print("Missing values:", missing_values_count.sum())
ins_zero_data = sfp_data.fillna(0)
new_missing_number = ins_zero_data.isnull().sum()
print("Missing values after insertion of zero:", new_missing_number.sum())
# Out:
# Missing values: 2245941
# Missing values after insertion of zero: 0

# %%
ins_bfill_data = sfp_data.fillna(method='bfill', axis=0).fillna(0)
print("Missing values after insertion by bfill method:", ins_bfill_data.isnull().sum().sum())
ins_bfill_data.head()
# Out:
# Missing values after insertion by bfill method: 0
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                    A
# 1           04/19/2016  0306  007            440                    A
# 2           05/27/2016  0595  203           1647                    A
# 3           11/07/2016  0156  011           1230                    A
# 4           11/28/2016  0342  001            950                    A
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# ...
