# %%
#pip install efficientnet

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf, tensorflow.keras.backend as K
import seaborn as sns
import random
import efficientnet.tfkeras as efn
import cv2
from tensorflow.keras import optimizers
import hashlib
import plotly.express as px
import plotly.graph_objects as go

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
import os
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\abhin\\AppData\\Roaming',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'EAGLE_EYE',
#         'COMSPEC': 'C:\\Windows\\system32\\cmd.exe',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'HOMEDRIVE': 'C:',
#         'HOMEPATH': '\\Users\\abhin',
#         'LOCALAPPDATA': 'C:\\Users\\abhin\\AppData\\Local',
#         'LOGONSERVER': '\\\\EAGLE_EYE',
#         'NUMBER_OF_PROCESSORS': '16',
#         'ONEDRIVE': 'C:\\Users\\abhin\\OneDrive',
#         'ONEDRIVECONSUMER': 'C:\\Users\\abhin\\OneDrive',
#         'OS': 'Windows_NT',
#         'PATH': 'C:\\Users\\abhin\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\cv2\\../../x64/vc14/bin;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Program Files\\MySQL\\MySQL Server 8.0\\bin;C:\\Program Files\\Git\\cmd;C:\\Program Files\\MySQL\\MySQL Shell 8.0\\bin\\;C:\\Users\\abhin\\AppData\\Local\\Programs\\Python\\Python310\\Scripts\\;C:\\Users\\abhin\\AppData\\Local\\Programs\\Python\\Python310\\;C:\\Users\\abhin\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\abhin\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Users\\abhin\\AppData\\Local\\GitHubDesktop\\bin',
#         'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC;.CPL',
#         'PROCESSOR_ARCHITECTURE': 'AMD64',
#         'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 154 Stepping 3, GenuineIntel',
#         'PROCESSOR_LEVEL': '6',
#         'PROCESSOR_REVISION': '9a03',
#         'PROGRAMDATA': 'C:\\ProgramData',
#         'PROGRAMFILES': 'C:\\Program Files',
#         'PROGRAMFILES(X86)': 'C:\\Program Files (x86)',
#         'PROGRAMW6432': 'C:\\Program Files',
#         'PSMODULEPATH': 'C:\\Users\\abhin\\Documents\\WindowsPowerShell\\Modules;C:\\Program Files\\WindowsPowerShell\\Modules;C:\\Windows\\system32\\WindowsPowerShell\\v1.0\\Modules',
#         'PUBLIC': 'C:\\Users\\Public',
#         'SESSIONNAME': 'Console',
#         'SYSTEMDRIVE': 'C:',
#         'SYSTEMROOT': 'C:\\Windows',
#         'TEMP': 'C:\\Users\\abhin\\AppData\\Local\\Temp',
#         'TMP': 'C:\\Users\\abhin\\AppData\\Local\\Temp',
#         'USERDOMAIN': 'EAGLE_EYE',
#         'USERDOMAIN_ROAMINGPROFILE': 'EAGLE_EYE',
#         'USERNAME': 'abhin',
#         'USERPROFILE': 'C:\\Users\\abhin',
#         'WINDIR': 'C:\\Windows',
#         'WSLENV': 'WT_SESSION:WT_PROFILE_ID:',
#         'WT_PROFILE_ID': '{61c54bbd-c2c6-5271-96e7-009a87ff44bf}',
#         'WT_SESSION': '94846f69-a97f-4810-94a4-8e16574a03b8',
#         'ZES_ENABLE_SYSMAN': '1',
#         '__PSLOCKDOWNPOLICY': '0',
#         'JPY_INTERRUPT_EVENT': '2512',
#         'IPY_INTERRUPT_EVENT': '2512',
#         'JPY_PARENT_PID': '2548',
#         'TERM': 'xterm-color',
#         'CLICOLOR': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://matplotlib_inline.backend_inline',
#         'TPU_ML_PLATFORM': 'Tensorflow',
#         'TF2_BEHAVIOR': '1'}

# %%
def seed_everything(seed=13):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
    os.environ['TF_KERAS'] = '1'
    random.seed(seed)

seed_everything(42)

# %%
def TPU():
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
        print("Running on tpu", tpu.master())
    except ValueError:
        tpu = None
    if tpu:
        tf.config.experimental_connect_to_cluster(tpu)
        tf.tpu.experimental.initialize_tpu_system(tpu)
        strategy = tf.distribute.experimental.TPUStrategy(tpu)
    else:
        strategy = tf.distribute.get_strategy()
    print("REPLICAS: ", strategy.num_replicas_in_sync)
    return strategy

strategy = TPU()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 16
#      13     print("REPLICAS: ", strategy.num_replicas_in_sync)
#      14     return strategy
# ---> 16 strategy = TPU()
#
# Cell In [3], line 3, in TPU()
#       1 def TPU():
#       2     try:
# ----> 3         tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
#       4         print("Running on tpu", tpu.master())
#       5     except ValueError:
#
# NameError: name 'tf' is not defined

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# IPython             cmd                 msilib              statsmodels
# MySQLdb             code                msvcrt              string
# OUTLIERS            codecs              multiprocessing     stringprep
# PIL                 codeop              nbclassic           struct
# __future__          collections         nbclient            subprocess
# _abc                colorama            nbconvert           sunau
# _aix_support        colorsys            nbformat            symtable
# _argon2_cffi_bindings commctrl            nest_asyncio        sys
# _ast                compileall          netbios             sysconfig
# _asyncio            comtypes            netrc               tabnanny
# _bisect             concurrent          networkx            tarfile
# _blake2             configparser        nltk                telnetlib
# _bootsubprocess     contextlib          nntplib             tempfile
# _bz2                contextvars         notebook            tenacity
# _cffi_backend       contourpy           notebook_shim       tensorboard
# _codecs             copy                nt                  tensorboard_data_server
# _codecs_cn          copyreg             ntpath              tensorboard_plugin_wit
# _codecs_hk          crypt               ntsecuritycon       tensorflow
# _codecs_iso2022     csv                 nturl2path          tensorflow_datasets
# _codecs_jp          ctypes              numbers             tensorflow_estimator
# _codecs_kr          curses              numpy               tensorflow_io_gcs_filesystem
# _codecs_tw          cv2                 oauthlib            tensorflow_metadata
# _collections        cycler              odbc                tensorflow_probability
# _collections_abc    dataclasses         opcode              termcolor
# _compat_pickle      datetime            operator            terminado
# _compression        dateutil            opt_einsum          test
# _contextvars        dbi                 optparse            text_unidecode
# _csv                dbm                 os                  textwrap
# _ctypes             dde                 packaging           this
# _ctypes_test        debugpy             pandas              threading
# _datetime           decimal             pandocfilters       threadpoolctl
# _decimal            decorator           parso               tidyverse
# _distutils_hack     defusedxml          pasta               tifffile
# _elementtree        difflib             pathlib             time
# _functools          dill                patsy               timeit
# _hashlib            dis                 pdb                 timer
# _heapq              distutils           perfmon             tinycss2
# _imp                django              pickle              tkinter
# _io                 doctest             pickleshare         token
# _json               efficientnet        pickletools         tokenize
# _locale             email               pip                 toml
# _lsprof             encodings           pipes               tomli
# _lzma               ensurepip           pkg_resources       tornado
# _markupbase         entrypoints         pkgutil             tqdm
# _md5                enum                platform            trace
# _msi                errno               plistlib            traceback
# _multibytecodec     etils               plotly              tracemalloc
# _multiprocessing    executing           plotnine            traitlets
# _opcode             fastjsonschema      ply                 tree
# _operator           faulthandler        poplib              tty
# _osx_support        filecmp             posixpath           turtle
# _overlapped         fileinput           pprint              turtledemo
# _pickle             flask               profile             types
# _plotly_future_     flatbuffers         prometheus_client   typing
# _plotly_utils       fnmatch             promise             typing_extensions
# _portaudio          fontTools           prompt_toolkit      tzdata
# _py_abc             fractions           pstats              unicodedata
# _pydecimal          ftplib              psutil              unittest
# _pyio               functools           pty                 urllib
# _pyrsistent_version gast                pure_eval           urllib3
# _queue              gc                  pvectorc            uu
# _random             genericpath         py_compile          uuid
# _sha1               getopt              pyasn1              validators
# _sha256             getpass             pyasn1_modules      venv
# _sha3               gettext             pyaudio             warnings
# _sha512             glob                pyautogui           wave
# _signal             google_auth_oauthlib pyclbr              wcwidth
# _sitebuiltins       graphlib            pycparser           weakref
# _socket             greenlet            pydoc               webbrowser
# _sqlite3            grpc                pydoc_data          webencodings
# _sre                gym                 pyexpat             websocket
# _ssl                gym_notices         pygame              werkzeug
# _stat               gzip                pygetwindow         wheel
# _statistics         h5py                pygments            wikipedia
# _string             hashlib             pylab               win2kras
# _strptime           heapq               pymsgbox            win32api
# _struct             hmac                pyparsing           win32clipboard
# _symtable           html                pyperclip           win32com
# _testbuffer         http                pyrect              win32con
# _testcapi           idlelib             pyrsistent          win32console
# _testconsole        idna                pyscreeze           win32cred
# _testimportmultiple imageio             pythoncom           win32crypt
# _testinternalcapi   imaplib             pyttsx3             win32cryptcon
# _testmultiphase     imghdr              pytweening          win32event
# _thread             imp                 pytz                win32evtlog
# _threading_local    importlib           pywhatkit           win32evtlogutil
# _tkinter            importlib_resources pywin               win32file
# _tracemalloc        inspect             pywin32_bootstrap   win32gui
# _uuid               io                  pywin32_testutil    win32gui_struct
# _warnings           ipaddress           pywintypes          win32help
# _weakref            ipykernel           queue               win32inet
# _weakrefset         ipykernel_launcher  quopri              win32inetcon
# _win32sysloader     ipython_genutils    random              win32job
# _winapi             isapi               rasutil             win32lz
# _winxptheme         itertools           re                  win32net
# _xxsubinterpreters  itsdangerous        regcheck            win32netcon
# _yaml               jedi                regex               win32pdh
# _zoneinfo           jinja2              regutil             win32pdhquery
# abc                 joblib              reprlib             win32pdhutil
# absl                json                requests            win32pipe
# adodbapi            json5               requests_oauthlib   win32print
# afxres              jsonschema          rlcompleter         win32process
# aifc                jupyter             rsa                 win32profile
# antigravity         jupyter_client      runpy               win32ras
# anyio               jupyter_core        sched               win32rcparser
# argon2              jupyter_server      scipy               win32security
# argparse            jupyterlab          seaborn             win32service
# array               jupyterlab_plotly   secrets             win32serviceutil
# asgiref             jupyterlab_pygments select              win32timezone
# ast                 jupyterlab_server   selectors           win32trace
# asttokens           jupyterthemes       send2trash          win32traceutil
# astunparse          kaggle              servicemanager      win32transaction
# asynchat            keras               setuptools          win32ts
# asyncio             keras_applications  shelve              win32ui
# asyncore            keras_preprocessing shlex               win32uiole
# atexit              keyword             shutil              win32verstamp
# attr                kiwisolver          signal              win32wnet
# attrs               lazy_loader         site                winerror
# audioop             lesscpy             siuba               winioctlcon
# babel               lib2to3             six                 winnt
# backcall            linecache           skimage             winperf
# base64              locale              sklearn             winpty
# bdb                 logging             slugify             winreg
# binascii            lzma                smtpd               winsound
# binhex              mailbox             smtplib             winxpgui
# bisect              mailcap             sndhdr              winxptheme
# bleach              markdown            sniffio             wrapt
# bs4                 markupsafe          socket              wsgiref
# builtins            marshal             socketserver        xdrlib
# bz2                 math                soupsieve           xml
# cProfile            matplotlib          speech_recognition  xmlrpc
# cachetools          matplotlib_inline   sqlalchemy          xxsubtype
# calendar            mglearn             sqlite3             yaml
# certifi             mimetypes           sqlparse            zipapp
# cffi                mistune             sre_compile         zipfile
# cgi                 mizani              sre_constants       zipimport
# cgitb               ml_dtypes           sre_parse           zipp
# charset_normalizer  mmap                ssl                 zlib
# chunk               mmapfile            sspi                zmq
# clang               mmsystem            sspicon             zoneinfo
# click               modulefinder        stack_data
# cloudpickle         mouseinfo           stat
# cmath               mpl_toolkits        statistics
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %%
print("To stop from losing streak")
